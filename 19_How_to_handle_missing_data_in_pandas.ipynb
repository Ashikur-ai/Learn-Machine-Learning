# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashikur-ai/Learn-Machine-Learning/blob/main/19_How_to_handle_missing_data_in_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn
np.random.seed(101)

# %%
df = pd.DataFrame({'A':[1, 2, np.nan, np.nan], 'B':[2, 8, np.nan, 5], 'C':[1, 3, 5, 7]})

# %%
df
# Out:
#      A    B  C
# 0  1.0  2.0  1
# 1  2.0  8.0  3
# 2  NaN  NaN  5
# 3  NaN  5.0  7

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  2.0  1
# 1  2.0  8.0  3

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  3
# 2  5
# 3  7

# %%
df>2
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True   True
# 2  False  False   True
# 3  False   True   True

# %%
df[df>2]
# Out:
#     A    B    C
# 0 NaN  NaN  NaN
# 1 NaN  8.0  3.0
# 2 NaN  NaN  5.0
# 3 NaN  5.0  7.0

# %%
df
# Out:
#      A    B  C
# 0  1.0  2.0  1
# 1  2.0  8.0  3
# 2  NaN  NaN  5
# 3  NaN  5.0  7

# %%
df.fillna(value=0)
# Out:
#      A    B  C
# 0  1.0  2.0  1
# 1  2.0  8.0  3
# 2  0.0  0.0  5
# 3  0.0  5.0  7

# %%
df.fillna(value=df['A'].mean())
# Out:
#      A    B  C
# 0  1.0  2.0  1
# 1  2.0  8.0  3
# 2  1.5  1.5  5
# 3  1.5  5.0  7
